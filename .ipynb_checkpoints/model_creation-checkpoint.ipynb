# %%
import pandas as pd
from sent2vec.vectorizer import Vectorizer

# %%
# Read in the dataframe
df = pd.read_csv('./Clean Data/clean_data.csv', index_col=[0]);
df
# Out:
#                                                  comment      label
# 0      went sister makeup cant find sample lipstick g...  not_toxic
# 1                                             car selfie  not_toxic
# 2                                     im finally get get  not_toxic
# 3      rt k michelle apart baltimore twitter shed one...      toxic
# 4      rt really get excited see bad bitch associatio...      toxic
# ...                                                  ...        ...
# 71584  he lying faggot used inspect element change nu...      toxic
# 71585                         redirect talk g u district  not_toxic
# 71586  victim adam saleh refers black people abeed sl...      toxic
# 71587                 ive year mostly amp even leave die      toxic
# 71588                           cause said dident shit u      toxic
#
# [71589 rows x 2 columns]

# %%
# Convert the comment column to a list of Strings
sentences = df['comment'].tolist()
# Out:
# ['went sister makeup cant find sample lipstick got looking forward using',
#  'car selfie',
#  'im finally get get',
#  'rt k michelle apart baltimore twitter shed one hoe saying shes celibate smh',
#  'rt really get excited see bad bitch association lunch everyday always make laugh',
#  'year ago day blast friend amp today',
#  'im orlando',
#  'oh see discussion already closed well problem ask rfc later article talk page',
#  'rt eddy teezy get pussy dont know always talking shit theyve never taken anyones girl eit',
#  'hey edits made legit vandalism legit player nickname placed format player nickname commonly placed',
#  'forum posting question actually direct copy article appeared edmonton journal person post forum basically copying pasting material journal site prefer could change reference journal article although would lead disadvantage people actually check reference unless happen copy journal question laying around',
#  'editing wikipedia shouldbe something making lot afds voting delete lot afds deleting content everywhere never encountered negative editor',
#  'amp bitch',
#  'wannabe',
#  'rt rt team trash',
#  'darling fucking',
#  'sell continues',
#  'bought wiley fox storm get tomorrow fully joining world today',
#  'sometimes dance around living room favorite song tune noise world',
#  'time go',
#  'think little disingenuous zet claim division lost fighting troop far destroyed fighting capacity close nil',
#  'weddinganniversary video greeting wish dear one weddinganniversary via',
#  'lmfaoooooo rt lmfaooooooopoooooo rt come yo bitch as auntie httptcoekllhpcv',
#  'must run brownie',
#  'rt see yall one yall side bitch made httptcopjodamfm',
#  'day welcome delegate across scotland',
#  'snapchat',
#  'bcoz white clean',
#  'see dumbass nigger',
#  'repeat put dog hot car leave heat keep home fuck sake',
#  'brisk_and_fadestay_here_forever__retro_rushngwebukhx_int generation hardcore',
#  'shut mind business go fuck one else',
#  'sexy nude persian girl naked',
#  'alarm clock callin lol wake yo as get money bitch',
#  'puma energy hi beagel hope well puma energy made couple foray new market namely uk colombia see talk page could look let know think great many thanks',
#  'bull shit switching rule http en wikipedia org wiki hugo p c rez soccer http en wikipedia org wiki thomas dooley http en wikipedia org wiki frank klopas http en wikipedia org wiki earnie stewart believe called precedent give julian green due owned yahtzee spank',
#  'bitch ralphy thanks httptcoaakwohdfgv',
#  'well well somebody today think',
#  'back model',
#  'get shit hoe',
#  'surprising read make gtgtgt betrayal ka ltltlt',
#  'pa mil rejected business amp must stoppe',
#  'made one time favorite look like bitch grandest stage em',
#  'dont ball hashtag say weasel away lumpy tony dipshit',
#  'blame person u one',
#  'alright bitch hope someone deletes life suck dick get hit bus',
#  'mammy push white baby like bitch',
#  'remembering life people died date dealing family death week feel heabreaking',
#  'u feel like kinda',
#  'damn bitch eddie johnson team last year',
#  'enjoy hour everyday draught beer imfl',
#  'happy birthday main niggah right minute dream bein rich httptcooyxyxhze',
#  'everything perfect amp family',
#  'spend day mam',
#  'teacher say basic algebra think basic bitch',
#  'rude rt wish bitch would stop calling im trying get dicked nigga',
#  'wtf chick singing th inning stretch giant game wearing shes like redneck carmen miranda',
#  'ness bull hill climb reach target complete task survive strong excite',
#  'lol niccas remember ginyu force',
#  'rt youre tweeting cringiest people darth dana bitch lmao follows r',
#  'got lot hoe dick',
#  'rt year two fan base unc indiana said thing right way uk others rogue ho',
#  'classed severe adverse reaction status epilepticus psychosis',
#  'still bunch nigger shoopsywoopsy p edit talk page see fit cunt head',
#  'green',
#  'broken record',
#  'sometimes simple thing best',
#  'welcome also thanks message talk page may utc',
#  'feeling around people friend family never ever fitting',
#  'course cnn wont address real truth hrc b bo lie meanwhile ppl kp dying ampsickening',
#  'rt thats bitch',
#  'u suck donkey ball yeah',
#  'rrrr one else killing oh watch abscbn news channel',
#  'rt bitch unnecessary thing lol',
#  'removing significant part page content without reason replacing entire page nonsense sometimes important verifiable reference deleted valid reason given summary however significant content removal usually considered vandalism reason removal content readily apparent examination content quoth wiki vand quoted numerous time without actually reading fuck ing thing removing dubious unverifiable content call vandalism lol failure',
#  'article semi protected edit account le day three think old',
#  'cipherpunk needed fixing copied syntax straight wp redirect make redirect',
#  'fu xck spk eat wait untill u china may country done file lawsuit wikipedia get banned due infringement upon sourcing information posted without authorization block idc auto ip changer',
#  'sigh turn light feather moment',
#  'rt dont play game girl play better bitch',
#  'kanye west faggot',
#  'hey little work resizing could work',
#  'slut bucket especially dan hoe',
#  'stop editing post dip shit right state opinion dont give shit consider vandalism worthless admin power trip piece shit stop editing post dip shit right state opinion dont give shit consider vandalism worthless admin power trip piece shit stop editing post dip shit right state opinion dont give shit consider vandalism worthless admin power trip piece shit stop editing post dip shit right state opinion dont give shit consider vandalism worthless admin power trip piece shit stop editing post dip shit right state opinion dont give shit consider vandalism worthless admin power trip piece shit stop editing post dip shit right state opinion dont give shit consider vandalism worthless admin power trip piece shit stop editing post dip shit right state opinion dont give shit consider vandalism worthless admin power trip piece shit stop editing post dip shit right state opinion dont give shit consider vandalism worthless admin power trip piece shit stop editing post dip shit right state opinion dont give shit consider vandalism worthless admin power trip piece shit stop editing post dip shit right state opinion dont give shit consider vandalism worthless admin power trip piece shit stop editing post dip shit right state opinion dont give shit consider vandalism worthless admin power trip piece shit stop editing post dip shit right state opinion dont give shit consider vandalism worthless admin power trip piece shit stop editing post dip shit right state opinion dont give shit consider vandalism worthless admin power trip piece shit stop editing post dip shit right state opinion dont give shit consider vandalism worthless admin power trip piece shit stop editing post dip shit right state opinion dont give shit consider vandalism worthless admin power trip piece shit stop editing post dip shit right state opinion dont give shit consider vandalism worthless admin power trip piece shit',
#  'bitch like need get fucked right every night',
#  'real life living person actually desire vote vindictive hate driven murderous conniving liar',
#  'join bandwagon would cost way much stupid exclusive wish theyd away pay',
#  'son bitch reader might wanna know shit would like deleted thing submitted one else problem information',
#  'godly u fuckin redneck peckerwood',
#  'fuck look like shopping trash as store',
#  'one sleep til get spend evening lincoln',
#  'making missed oppounity creating new one training adventure tomorrow',
#  'rt u nig im light skin dark skin mentality lol black',
#  'must see tomorrow soumya ki entry color pm',
#  'rooster simulation want climb vast expanse mountain reached le',
#  'goodnight pretty bitch n real nigga fuck da rest',
#  'father day dad one heaven',
#  'wish father day',
#  'got im',
#  'somebody who much moron pussy doesnt belong force',
#  'sorry editing max hohar freand run bro hack like harry potter cast spell mum high right bored go fuck self asian prick',
#  'waiting th june first match first day',
#  'well wouldnt coast much dont see going bass fishing bunch rich redneck either',
#  'know ref amp ref accepting',
#  'father day please gift hospitalized child',
#  'im crazy bitch call time one hour',
#  'lost brain cell comprehending garble',
#  'oscar amp used make fun chacowearing people together theyre sale lil bitch want',
#  'matter dude skin color ok bad b',
#  'rt oreo cheesecake bite httptcoyboqrrtjyt',
#  'crimea ukraine article hi hj message left talk page explained reasoning protecting relevant article response indicates share opinion understand coming comment also said really like avoid protecting duration avoided keep bringing issue attention utmost make life easier bring issue attention part see rr request filed user kudzu sort gone past lot disruptive anon ip causing trouble page pretty much full blown sock puppetry abuse multiple account least though likely one person life made easier spi already filed one one sock master though probably different person user filed others example problem notice cu even gotten around spi filed time cu get around considering case person behind account already thrown away moved onto new spa keep thing sure best course action helluva frustrating trying deal',
#  'seems like ignoring reality dividing amp weakening amp',
#  'happy birthday faggot',
#  'find away use japanese app',
#  'comment reflection ignorance',
#  'something like perfectionist even check horoscope bitch',
#  'maybe ill love one day maybe well someday grow till sit drunk as runway hoe',
#  'im happy',
#  'friendzone',
#  'see prettiest girl strip smoking good as cigarette face smh',
#  'false friend slavist recommend talk milo ran study slavistic',
#  'dadwherever areyou gone never forgotten',
#  'polar bear climb racing angry polar bear climb racing polar bear living cold place look',
#  'wingin amp hoping best',
#  'sunny perfect weather water',
#  'video time ending ontop',
#  'rsa lab emc mit acm wrong vquaker used accepting correction due life cannot understand cited information primary source rsa lab fourth factor authentication worth knowing confronted information legal requirement far know must spurious people know better get legal information government source wikipedia holding resource type cfr usc guide exposition sanctioned resource believe u government would like hear idea someone know know part network administrationwhich part brilliance needing cohort supervisor provide human factor difficult defeat though suspect know already offended though immensely confused item access control must devoid technical information meet arbitrary legal standard would ask user loses smartcard e cac forgets password premise biometric device inherence factor methodology deployed situation administrator knowledge user ask terminated reissue credential based knowing person organization terminate said expounding th factor would mean citing information available lay hope talk without citing df would consider common knowledge set provide reliable information mission changed well could tell consider non contributor onwe allowed use wikipedia anyway work anathema say want unless surprise someone ego check issued expect nothing le teach changed tone dumb ing use nonsensical example could used authenticate someone smell non sequitur gave thing read still waiting cite wikipedia policy information legally sanctioned format expected barrister cited sourcewhere citation language style organization applicability line one regulatory body better way proactive would realize academic database access elsevier jstor edas ie springerlink pricey try yet without stuck google funk digress full reference fourth factor cash register key manager us return something yep someone know around decade sign account isp take joy knowing sheriff star part helpful realize alone set standard repent ash wrend sackcloth accordingly',
#  'fuck fuck vandalize sandbox as hole fuck ing editing experiment',
#  'rt social network got bitch head like httptcobhmuoxvu',
#  'today day',
#  'got money gun gold bitch nd stack nigga fuck net beef shooter get nigga bring dat friday den',
#  'alex box',
#  'rt still trying hit hoe httptcojbhjmpygx',
#  'innit totally gay shit',
#  'prison officer goaded inmate needed restrained pa game',
#  'bitch dont care play role',
#  'yasss bitch yasss wonder penny passed',
#  'savage mean fucking retard yes correct',
#  'keegan found proxy one last sock though',
#  'tonight spagetti bolognaise scrabble dd amp dd came home work new book one',
#  'still blaming bush fucking retard',
#  'rt bitch',
#  'barrys whitey brownshirt run wild oakland following lead nwa punk chant f police httptconburmtj',
#  'fruit brings smile face',
#  'rt thats drive bitch httptcodrkctxtq',
#  'ill show chug beer',
#  'lmaoo boy think benny heard lol blasting bitch',
#  'know fuck go revert edit pointless talking brickwall',
#  'idiot',
#  'looking forward new season',
#  'temptation blame everything scapegoat strong resist',
#  'one hour sun omotesando',
#  'might buy arod jersey',
#  'edit plane edited reaction engine user talk contribs',
#  'club every week bitch get life',
#  'reality reality',
#  'teacher talm bout would make every senior go da army fa yr bitch please meat ainnn doin uh damn thang',
#  'never appropriate zero idea im feeling right',
#  'used fat bitch everybody made fun look made fun ugly',
#  'bird amp bad family rhyme lyric via',
#  'national best friend day',
#  'draghi international use euro fallen slightly',
#  'bird fallen chimney trapped nothing get',
#  'cant help laugh xd',
#  'rt knicks still trash melo signed money dont even care good winning team',
#  'likka downtown bitch secondline rt man yeah thats ball game teddy bridgewater gettin hit',
#  'merge logrus pattern neither logrus pattern sufficiently independently notable justify article two article merged',
#  'rt bitch httptcogmjkolmcyq',
#  'make overweight dog',
#  'cold war fought oil',
#  'mr g bitch thats mr grohl dont know',
#  'youve good friend glad got honkie as let fuck shit year',
#  'playing dustin ohalloran opus music song',
#  'bitch u know mean spell champ nut',
#  'fag',
#  'trying destroy fuck ing article trying add something actually useful trying best find fuck ing source get fuck ing back',
#  'somebody come look niggah right kevin hart voice lol httptcormhwqcjt',
#  'legenda born happy',
#  'rt fat nigga aint ever gotten broad anything content character dont bitch think im sex',
#  'customized canvas wall',
#  'jihadis identify man one carried massive suicide bombing speicher camp httptcohhjhynby',
#  'love ho httptcoiobsnjj',
#  'photographeraist look',
#  'bitch compared dick pencil get sharpened like dont sharpen pencil becomes useful',
#  'rt rather fukk bitch dat fukks eryday den fukk dat bitch try hol n cold whore n da sheet cnt een look',
#  'big red fat squaw lol hubby funny',
#  'still cant get donald trump poor sentence structure skill',
#  'hell wrong humanity would anyone need anything prove faith',
#  'rt charlie rangel rewrite history gop think civil war httptcomoceubrutf',
#  'right far im concerned aint bitch tf',
#  'feeling kinda blue n',
#  'deleted comment fuck ing pussy',
#  'rt emma watson httptcoineoglig',
#  'idiot anyone favor abstinence sex ed fuck ing idiot deserves eye gouged corkscrew',
#  'twitter fag',
#  'never show ad',
#  'everyone el parent use refer power puff girl powder puff girl mine exceptionally retarded',
#  'amendment discussed thanks',
#  'muyou suck as hole ch',
#  'show good faith actually updated bio tidied bit etc definitely mission article notable individual article undoubtedly fall within scope contribution far appreciated c',
#  'gotcha thanks mom',
#  'u coon watching love hip hop aint',
#  'stunning colour along morning route today',
#  'lover stop angry visit usgtgtgt',
#  'rt american claim local threat reply mean iraq syria turkey jordan saudi arabia leb',
#  'regrann',
#  'thinking parent yr old toddler snatched alligator reso',
#  'one welcome new eastern panhandle overlord hope better job yokel got u first place',
#  'lick ball suck ing arse',
#  'searching incredible story white man quest find ingredient necessary make caribbean jerked chicken redneck land',
#  'im hoe forgetting umbrella',
#  'hoe beefing bout important hoe queefing yall blowing vaginal wind back amp forth stfu amp get money',
#  'bitch tryna get free promoting n shit lmaooo see tha cut',
#  'orlando needed another shooting christina grimmie',
#  'saw lady look like honey boo boo mom goddamn bitch ugly',
#  'oh gonna explain kid get older got pussy failure father hahaha easy',
#  'im mother fuckin gt gt gt type shit joke rig gt',
#  'canceled disneyland firework day go waited year see new show',
#  'pay pussy yo get many freebie',
#  'aint cuffing bitch thats posting sex gifs maybe im different',
#  'probably going tackle kenzie see tbh miss bitch',
#  'rt bird fucking',
#  'changed see also section marti made littlefighter met starski yet',
#  'rt check ya bitch',
#  'suggesting start as kissing instead get',
#  'road',
#  'wednesday',
#  'lil bitch vet say need dog',
#  'called monkey lol \nrt \nif shoe fit cause sure look like married one \nhttptcofpgdalfaa',
#  'belum ku liat si maybe soon insha allah gonna watch',
#  'make make much long',
#  'amazing thank much',
#  'trust tweeted like damn im fag',
#  'tell hoe im friended',
#  'hey meani head change fun fact patrick henry wtf methinks homoe sex ahye run momma would ahamed told last night dang ho',
#  'mom told put drug paraphernalia trash shitty life stoner cop mom im pretty upset',
#  'went ya bitch house virgin anymore',
#  'like great small tablet vzw huge mistake',
#  'new baby',
#  'buddy drug whole train lmao good extra as hoe hate ny hoesme',
#  'lt tell someone woh today',
#  'sort offense include inserting nonsense article blanking article otherwise changing article obviously unwanted content serf purpose creating work wikipedia editor administrator continue account ip block jun utc',
#  'hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard pro assad hanibal bastard p',
#  'sock single purpose actcount created miutes ago know use wikimark already look legit writing random crap user page almost certainly abusive sock trying get around rr cause others checkuser enlightening quite sure crated user page wrote someting talk page avaoid red link within one minute made edit wanted almost certainly scokputter established user deleted user know exactly minute edit designed tempt violating rr make imposible keep appropriate tag article think know either sock meatpuppet established user involved editing article',
#  'wish amp family let work together remove world',
#  'utc please continue help could please continue presence yoshiaki omura page took suggestion made edits citated etc crum within second reverted censorship august',
#  'join',
#  'hate hoe try play wifey roll',
#  'look like outline nailed',
#  'amp feel like stomping listen',
#  'rt one loyal girlfriend worth one hundred hoe',
#  'maybe much ask shatter already broken hea',
#  'mother fuck ing idiot stupid hell know nothing butt business superior',
#  'sheikh romance book lisa love',
#  'focking luck who croatian havin sone',
#  'want birthday big booty hoe',
#  'rt ill throw cheeseburger bitch as',
#  'im ready bounce dis bitch',
#  'really happy relationship finally much better one first',
#  'im sure would add helpful parenthetical explanation redneck peckerwood teabaggers httpstcozkqgwfer',
#  'leftist predictable amp',
#  'rt never invest money broke bitch',
#  'matai ngeli alu polosi ho nifo',
#  'thankful',
#  'hey turd cutterstop tweeting juvenile shit job teabagger',
#  'datsyuk always favorite red wing man one year',
#  'rt lil skinny bitch throw ha like frito \nbol',
#  'happy people people wise guy',
#  'jesz one anothers',
#  'iknow couple mf favorite line wouldnt thats young bitch stopp young minded',
#  'cant argue bitch nigga',
#  'dress tomorrow mock interview still dont know tie tie',
#  'rt anything said bout mom b would led bitch getting stone cold stunner',
#  'main woodsford lost lb fearing wouldnt see kid grow h',
#  'well see consensus formed show indeed pov bad judgement part thanks comment anyway coldplay exp rt let talk',
#  'commercial showing interracial couple attacked suppoers',
#  'never enough',
#  'hoe still shouldve known',
#  'feel like bike today experiencing post withdrawal memorable weekend',
#  'thee bear trash tho',
#  'post link national review nerve go moniker neutral arbiter kind bull shit',
#  'stick as hole',
#  'ooowwwwww por fin',
#  'rt halloween spoopy hoe pimp daddy httptcooqvpeghx',
#  'american government preaches bullying\ncreating new generation pussy httptcofbguckwc',
#  'think noone saying failed state part state organization resulted quite livable situation seems due sometimes case somaliland despite fact permanent central government ligitimate monopoly power fact promising thing happening somalia outside central government good thing stress state moment characterized failed state definition somalia used differently please provide source environment read environment section apart nuclear waste issue problem seem mentioned explicitly solution planting tree campaign etc actor first env org prize winning people etc could someone knowledgeble subject make introduction paragraph main problem discussed maybe also reduce env activism part',
#  'oitnb today im shift staing night tomorrow life u dis',
#  'dont know dont misinform belmont park bigger flemington tight theredid watch',
#  'hopefully dems understand really think pay divided point',
#  'daily express row sour denchs bronte society yet bitter',
#  'really need list lol forget race',
#  'poor soul rt cuz fat bitch thing like',
#  'thing working black people bitch never fucking time wanna complain short check bitch dietoday',
#  'fuck people information found',
#  'aint bitch got shit',
#  'appealing',
#  'use power mind body',
#  'usd limited upside risk nearterm scotiabank',
#  'realdonaldtrump wtf want see photo trump post office idea pit',
#  'bitch ungrateful httptcoebgwbx fr lulwhore',
#  'rt silent protest philadelphia performance artist protest murder mike brown passerby mock httptco',
#  'rt nigga get married start dissin single bitch smh rt bitch want allowance date still singl',
#  'greaser film idiot bye',
#  'fathersdaymessage buy thing h',
#  'knew doc one tonight episode wthe broken hea',
#  'suck hate suck',
#  'osli idiot want deface srebrenica massacre article already discredited serbian source wanted opinion moral equivalism accused serb run rape camp participant gen lewis mackenzie heard srebrenica massacre article keep srebrenica genocide denial left revisionist website welcome osli also wanted include belgrade already discredited lie serb killed included article already discussed discredited allow srebrenica massacre article poisoned moral equivalism osli drop dead loser',
#  'cheeky thought rooster crow',
#  'hey everyone',
#  'bitch look yo favorite shit',
#  'delete account shallow go away',
#  'oprah winfrey network',
#  'ive editing video whole night time sleep two hour',
#  'first recital week alum still great',
#  'fuck ing stupid liberal like',
#  'nigga burning amp wont let know amp female burning amp wont let know',
#  'rt dyke surround httpstcoywegzsom',
#  'selfie sunday',
#  'pussy as people gun knife foh appreciate people still willing throw hand _',
#  'fuck ing huge ego fuck ing geek life',
#  'rt im bitch sweetheart u feel',
#  'surprised didnt understand speech im sure suppoers didnt either',
#  'charlie furbush',
#  'rt british jihadi mother want first female executioner mi wanted httptcoinzpvpftn',
#  'bitch thotting long get exposed something decent get overwhelmed',
#  'mirror like dad thusly trauma p cunt',
#  'id kill bitch able cuddle right ugh sucker stupid shit swear',
#  'cheetos taste likka steak right nah boy bitch going dumb',
#  'hey dick ole gonna fuck assface fuck shit fuck er',
#  'playing suzanne ciani full moon sonata',
#  'today one stop',
#  'people backwards',
#  'joy',
#  'atlast wait end',
#  'people life cant afford let go life',
#  'orange going anime aired july',
#  'little baby true love playa del',
#  'im sooo upgraded new haul',
#  'bet hc white would fired year ago',
#  'serbia recognise abkhazia south ossetia surprised georgia recognises kosovo retaliation',
#  'eyebrow fleek ya pussy stink',
#  'rt charlie strong took longhorn logo player helmet earn back\n\n httptcohvnujtss',
#  'unbelievably unprofessional unhelpful rude shine well truly removed stephen new suit',
#  'happy nd anniversary ruby couple charlotte amp jp fun wedding',
#  'got k follower n bed sheet last month bitch confrused voice',
#  'toptags',
#  'rt fella remember stock thermal timbs dyke buy',
#  'spoiler thinking adding information article far avoiding putting spoiler guy think done mean know wikipedia policy forbid personally like coming research vn reading careful avoid spoiler casually placed throughout',
#  'tommy fuck yo couch nigger',
#  'wish would make phone damn screen dont shatter cost arm leg still gotta pay fix em',
#  'rt rt like \nbmth\nadtr\nptv\nymas\nsws\natl\nomampm\naa\nmiw\nbtf\nwcar\nmcr\nafi\npe\nbvb\nwim\nbc\nss\ncte\nnsn\ngd\nwatic\naa\nbfmv\nfob\nf',
#  'tonight hour brand new season return finally',
#  'apple time nomnom',
#  'time sing ole ole ole seeing rain outside',
#  'touch edits mother fuckerucker fuck angry co ur poem suck',
#  'simple rule life',
#  'cant wait excited watch lemans year',
#  'true',
#  'isi burn alive girl feminist west complain mythical patriarchy wage gap',
#  'many nigga enough hoe nigga acting like hoe',
#  'tried hoe sinf',
#  'bitch dont even go fun anymore go tweet function take pic wit bitch',
#  'former towie star charlie king come httptcoyuxkxbcyt \n\ninspiring congrats welcome family',
#  'go fuck get job hippie shit bag',
#  'sad world',
#  'give permanat block raseac remember muslim dont worry image trying hurt u cant look image fake nothing islam prophet even article lame wikipedia authentic source encyclopedia kid authenticity anyone edit write w hate ver think like raeasc see know islam talk forget wiki lame authenticity recommend add pissed christ jessus article',
#  'brilliant bit many dont get touch may able help',
#  'last second',
#  'haha im vacation end',
#  'jpy rebound towards dma risk recovers fed eyed',
#  'pro condone everyone entitled opinion democracy',
#  'bitch keep looking choosing nah',
#  'friend',
#  'okay number aint saved long okay thancc tf hoe',
#  'finally found way delete old tweet might find useful well',
#  'corrected thee countless ahs china',
#  'looking forward going monday first ever time mile round trip hope woh',
#  'im sorry talk shit first allowed defend tell thing told coming',
#  'borrowdale brooke harare zimbabwe',
#  'mitt romney gone take away weave become president hoe gone walkin around looking like lil bill amp calliou',
#  'sspx join autistic pope rome go fuck sin maggot brain turn soup',
#  'oh cunt evaded block user samlaptop oh fuck shit cunt think block idenfinitley',
#  'lmfao putting twitter see fat bitch',
#  'may behavior talkpage honor harrington par know take defeat grace start behaving childishly let warn next childish edit likely result mention wp ani user review',
#  'pastor join u tomorrow libey city church christ morning worship afternoon worship pm',
#  'boston near ct phd figure boston busniess cultural hub ct far business concerned even hartford might disagree besides ct ny region know nyc business cultural hub america',
#  'good luck wikipedia suck oh look award certain make feel good inside persistant see feed shit man',
#  'woooohooo im going daunting buying ticket im super learn game amp meet everyone',
#  'hate cute as girl wack af boyfriend like bitch youre settlling quit settling real nigga',
#  'bitch talk shit',
#  'nav box point article article tablemannersc',
#  'wanna slap couple yall bitch',
#  'offical officially eye mass',
#  'veritable pastiche fathersday',
#  'rt dis bitch httptcovbcpjnvi',
#  'bitch im sick',
#  'rt update u still bitch',
#  'thankful good night sleep',
#  'consumer price index yoy meet forecast may',
#  'hate yal id delete twitter somethin better bitch as nigga',
#  'think everybody smile speak stranger tomorrow xx',
#  'nah shit get heated smartest mouth know im get called retard im done playing game',
#  'term jihad highlycontested concept',
#  'bitch probably deserved lol',
#  'show lotta love sister tho bitch predictable im trouble',
#  'today date hour would good announcement look fancy isnt',
#  'long yellow bunch track sweeping ton taken opportunity pit',
#  'probably best m ive ever spent bike taking m previous pb',
#  'time hop make realize much faggot lol',
#  'imma bitch know leave alone',
#  'let stop think jimbo gif thing gone since started maybe voicing stubborn could rethink unfair characterization admin come tell going review block jimbo animation make nauseated never taken seriously admin state reply essentially fault review block think would react attitude like consider statement made obviously better communicating really mean hard read page said first place would reacted instead know stated initially would understood reasonable statement observation want people problem reading page problem removing jimbo gif page snarkily saying jimbo gif make one either annoyed nauseated keep others taking seriously neither helpful clear real issue',
#  'mean youre balling youre jewish lol dont love hoe lol',
#  'bitch two job starting school th',
#  'weve used word cunt almost time beautiful',
#  'thankful film',
#  'order today',
#  'change bitch everything\nfor example girlfriend dont like crew hang bae',
#  'meet eat bitch',
#  'im ready today httptcogjnmow',
#  'angry fuck bitch',
#  'go fuck faggot',
#  'hiho httptcoficfnrutz',
#  'bruh rt ugly hoe say nigga arrogant',
#  'benefit nutmeg',
#  'sonoma county cannot handle gutto style straight north bay pussy forever',
#  'bull dominate bull direct whatever want yo',
#  'ok today good bc realized dont see fake bitch grade three whole month',
#  'strongthanks donated blood injured victim god bless died',
#  'thank baby sarap po',
#  'hang hour stas soon monsat pm',
#  'maple room bitch sacto style',
#  'coward site must stop changing thing right change right change nichiren shoshu website nil stop changed web site past mothns whpo think didnt predicte year ago would pissed however reborn huam long time changging site think buddhism act',
#  'stunning',
#  'bum as bitch block drawin',
#  'send inauguration join today',
#  'year please get school pm tomorrow',
#  'preordered sound really great book',
#  'rt denial bitch',
#  'repeat bitch',
#  'rt thing remember\nsometimes bitch necessary\nstick guns\nimpromptu solo dance party good fo',
#  'hate bitch like love much lt',
#  'rt st time eating pussy thought supposed literally eat ended biting clit really hard havent',
#  'suck dick',
#  'gonna take rt hoe gonna let come spend money themlisten',
#  'love nah bitch aint love',
#  'fuck king ugly',
#  'ive trying get info vigil tonight doesnt bother update anything',
#  'life isnt finding life creating',
#  'finding dory soo good',
#  'rt ayyy fag',
#  'life taken gay',
#  'wake way',
#  'sentlel offence find self bored sunday afternoon used look forward day ay day',
#  'wh enemy deployed google illegal manipin eu fined bastard bill manipulationlawlessness',
#  'got bitch though',
#  'there nothing like buying new gym gear cant wait tomorrow',
#  'pussy whipped',
#  'cannot wait go see finding dory',
#  'hea go family lost loved one orlando shooting',
#  'fuck fiskeharrison go suck dad dick',
#  'id give anything touch hear say dont worry love everythings okay',
#  'get rid egoless tuesday',
#  'chill',
#  'monday like saturday bitch',
#  'third party reliable source exception could u explain meens sorry annoying want get topic many source give find tell need please',
#  'happy angies dog theo',
#  'aww yeah good bing bong bing bong',
#  'bitch made nigger',
#  'young beautiful',
#  'yo fault taking nig everyday',
#  'httptcobpuqzyft evilyn fierce naughty girl next door pummels pussy purpletoy httptcoetbmzezao',
#  'minute silence victim orlando',
#  'educator derogatory name calling us go value school try instill',
#  'cant believe venue didnt see',
#  'lmfao found diary complaining bitch tbt im dead httptcoplqsasb',
#  'reason im quick dip bitch',
#  'tiny looking like albino red nose pitbull dope boy trap house',
#  'countdown till asshole gone obama moron creepy uncle joe bye bye scum',
#  'time put ski',
#  'spider man cultural influence hello please explain deleted reference world tallest building added promote cause thank october',
#  'rt fuck dat bitch',
#  'actually looked said heck rehired mean oh making play retired',
#  'office fuzzy sock favorite blanket literally need life rn',
#  'evergreen college police cant park properly open parking lot',
#  'know really liked go fuck',
#  'rt scott walker investigate christie bridgegate perry drunk monkey dem dagate men innocent threat left',
#  'youre definition hen inviting fox onto henhouse',
#  'typing cock mu mouth',
#  'im trump suppoer ad speaks volume ab endorsed tue',
#  'im bitch reason think im funny sometimes',
#  'let try edit anything yet unless confirmed operation proven successful ok add wikipedia rebel know give unreliable information',
#  'fuck ing bitch shut fuck as hole u wiki admin as hole cuz u w hate ver u want fuck yoy dianna tele jimmy wale as hole created shit call website fuck admin bitch let fuck ing suck as band get wiki page way better one mean yall fuck ing as hole',
#  'got',
#  'ever call poppy bitch mario',
#  'tale photographing yellowstone',
#  'like bitch better chill oh hey maria',
#  'see worst people',
#  'bitch goin',
#  'ate animal cracker',
#  'yea listen hoe wake',
#  'hey as hole tell constructive fat mother whore allahu akbar backdoor slut',
#  'posted entry buttermere horseshoe',
#  'see u',
#  'mention beer nearly top truly disgusting beer list',
#  'day day beautiful day puppy',
#  'february please vandalize page edit history europe continue block editing',
#  'yall pussy swur',
#  'muscle mammal form striated muscle fibre expect',
#  'sister time',
#  'cfd nomination category wikipedia administrator nominated deletion opinion matter welcome please participate discussion adding comment discussion page thank',
#  'u nigga dnt like bet fck yo bitch tho',
#  'soggy happy rhino',
#  'play england v russia marseille expect high risk game plenty time drink',
#  'dont want read',
#  'ltlt closet muzzie',
#  'bitch say cant dance httptcogkzjqndif',
#  'like got death touch rt bitch standing front looking like rogue xmen',
#  'easiest way sex chick smell good make laugh take get food fuck right pussy',
#  'mean bro fucking faggot',
#  'gother ticket edgelit quad derby anyone got advice soak atmosphere',
#  'wld u wanna faggot dude thats faggot like',
#  'wonder paid reffs cant believe im watching right',
#  'thought camera would steal soul shut fuck stupid twat',
#  'trash tho rt edgewood basketball court',
#  'nigguh dont mean youre pussy bomb',
#  'yall bron dick lose yall gone bad mouthing dog',
#  'amp line poetry haisl kro gtno add follow gtfor eid poetry',
#  'dog bite',
#  'indeed learning curve amazed much learning order get wiki privatized fully operational first wanted make iron clad security main page like arbcom wiki terribly difficult gaping hole mediawiki security default installation whereby uploaded file generally image completely private wiki directly accessed anyone familiar mediawiki merely typing url path took reading trial error mediawiki excuse mediawiki designed open everyone man like openness thing care think security mind image cannot viewed via intelligent url typing however making private wiki care want viewable p thumbnail image work matter localsettings php file like many thing would go talk page mediawiki discover many others wrestling issue turned imagemagick omitted recent build mediawiki moreover installing imagemagick matter dropping file folder wiki using ftp linux installer rpm webmaster done bunch gotta template like template xt template template doc template hilite template nbhyph template nowrap template xt think gotta have shepherding author sponsor bunch fond complain free stuff mediawiki amazing product commercial interest could match take poor documentation associated open source software day',
#  'eagle fan always annoying faggot',
#  'ace water spa coffee ulit',
#  'nigga loyal pussy call still thirsty fuck like bro go fuck woman amp get hormone lol',
#  'vandalised condemns act',
#  'actually look olethros look scripture olethros store goat',
#  'sunday family',
#  'throwing back sta journey',
#  'two demand leave flagship alone tech page lnnzman got drop dumb fake british thing cheer',
#  'rt rt got interest tall skinny model bitch like woman as amp hip',
#  'run away cuban heritage he proud beca',
#  'book enduring conviction fred korematsu amp quest ht',
#  'caught girl rubbing pussy nude beach httptcohlgitfyie',
#  'period',
#  'unique ghetto hell',
#  'stop vandalizing seriously mang got nothin better fuck vandalize talk page error message mean like omgrofl',
#  'saddie fattie fattie',
#  'fuck iowa idiot real baseball team signed p',
#  'dog big grin smile world smile back',
#  'intention side canvas need report issue requested closed discussion place suggested tried convince user direktor explain reverted sourced edit replied english poor permitted write en wiki caught egg chicken situation talk place talk place counterpart refuse discus top cannot react insult want dirt hand',
#  'let say',
#  'come davis show celebrate retard',
#  'today',
#  'scandal sex scene air abc right great pumpkin charlie brown making parent angry httptcovltspkus',
#  'agree hasnt much way original content aaa studio',
#  'keep talking im going make u cant talk u going talking like retard',
#  'epic fail ha ha ha ha failed goodye bitch e p fuck',
#  'laughable tried editing completely civil time incorrectly accused sockpuppet banned without evidence presented fact tried appeal admins mocked appeal address argument told need play nice wikipedia want new editor know completely bull shit wikipedia really wanted new editor falsely accuse ban people shit guilty know truth get banned wrongthink nothing wikipedia really policy hell even show account want would bother making another one would get banned without justification',
#  'day bitch letting anyone hit raw',
#  'nonsense already said white trash empirically proven article basically declared incestuous group see footnote upon want talk nonsense let see proof idea westboro member related blood otherwise keep adding shit cram elitist zomg registered user free encyclopedia attitude',
#  'lead investigator kathy robb team member penny setting equipment',
#  'even successful trader sad life',
#  'ongoing series keep solution guidance check wattpad koalamuffins',
#  'le parent also apparently already bought new car clue also meant u kid',
#  'know answer legally possible private citizen violate another private citizen civil right know section nelson charged federal case anyone could explain would appreciate argue whether outcome state murder trial justified really concern since dead letter concerned whether subsequent civil right prosecution legal state murder acquittal miscarriage justice first time look issei sagawa part mature understanding sort thing realize criminal justice system perfect inevitable innocent people convicted guilty people acquited time time price pay legal system end someone make decision sometimes may necessarily get right think going limb say sagawa case completely beyond reasonable belief',
#  'told bitch idgaf benz bitch',
#  'bitch new amount shit spoke bout twittah lol',
#  'national reason happy cub could',
#  'highest happiness eah happiness marriage william lyon phelps',
#  'hillary dodo bird candidate httptcoyfubgwqtw via',
#  'sound like bitch',
#  'eyebrow like wall street home rt rt yall bitch wilding pencil httptcowxwrbeeok',
#  'gay leader yamla gay nigger saturn jupiter hailing name wide butt size city paris',
#  'pau pissed like boozer pissed bull fan soft faggot',
#  'someone tell dread part uniform id pull hair trash talking cut doodoo braid',
#  'fundrasing as setting aside protypical psychotic paranoid ramblings mumbling danger ann coulter left wing kook thought dummkopfs er mean solar system exploration physicist would encouraged know well phase ii stop funding plan worked forcing wikipedia change see link http wikipediaclassaction org truly big daddy p told nice mean big daddy',
#  'aww yay',
#  'rt bruh always sooooooooooooooo tired never sleep im like new specie retard disrespect',
#  'adam west rt lmao trash b httptcotsvumwhu',
#  'ive lit fire cheer cold',
#  'rt havent cable crib year dont give damn bout tv show like hoe n hip hop',
#  'need book mine soon',
#  'wah guy spammed look like fuck ing saved as',
#  'rt kanye gt tupac serious yep bitch keep moving',
#  'hate bitch wear fake as ray ban theyre stop cheap',
#  'rt u got cotton mouth u eat pussy',
#  'find hard believe ceelo raping hoe easy get panty successful',
#  'e n ready big debut tomorrow',
#  'let honky know man lol',
#  'dog blue congestive failure treating medicine however way fix dog broken hea',
#  'fuck never stop fuck ing harry potter fan harry potter suck z fuck ing porn face',
#  'life depressing sometimes',
#  'miss bitch',
#  'top story featuring',
#  'read first page valentina canos novel rose master immediately wowed image explode',
#  'hold fate republican pay tiny tiny tiny little hand',
#  'attack bull chase leave lot despite fact youre strong source fo',
#  'gansitos atg beaner candy',
#  'gonna watch',
#  'tag placed beezwax requesting speedily deleted wikipedia done page appears meaningful content history text unsalvageably incoherent think notice placed error may contest deletion add top page existing speedy deletion db tag leave note page talk page explaining position please remove speedy deletion tag page created test please use sandbox experiment would like feel free leave message talk page question please remove speedy deletion tag page created considered vandalism use tag specified question leave note talk page',
#  'administrator elitist bastard care anyone say vast majority administrator pompous overbearing control freak run around attitude sysop sort right priviledge permission bully harras generally act like dick thinking get away cabal make sneaky back door decision deletion vote stacking block trying force editor rr page protection et cetera almost daily would seem person think admins total fuck wit attitude problem block reason whatsoever dick ead feel abuse power',
#  'shower time didnt hit snooze took slowtoo slowtweet time got cut sho',
#  'keep amp watch sign problematic conflict via',
#  'first big gig moro cant wait see bedgebury',
#  'rt bitch wit baby ask switch seat family could together said bitch family wasnt together',
#  'bihday sexy girl girl top boy naked',
#  'wouldnt trade world',
#  'rt ik vraag al maanden af hoe de nl pers zich al een stel hoeren gaan ge',
#  'im sad',
#  'call duty bitch',
#  'rt wow rt lmao rt bet ever come house dirty bitch httptcoqvruzgsfj',
#  'love mature age',
#  'taught eat pussy cut hair\ni taught eat pussy hair\nname movie',
#  'never go bed without wakeup without',
#  'first time lol httptcomitmfpvvlw yuhhhh hit hoe',
#  'ministering rev chris mbamalu topic time come text luke fathersday',
#  'god part fuck dont little pimply mouth breather understand cna get girl e king shit mountain huh laugh',
#  'suck dick tho thats better brownie',
#  'u taber shit coon',
#  'asscrack liked lot use',
#  'people questioning orlando shooter gay seen many shiless mirror selfies guy took',
#  'want oreo amp milk honestly stop store amp pick way back lol',
#  'know lookin like goatfucker',
#  'good time band rehearsal tonight ready rock tomorrow night',
#  'high mighty dirty cunt want perish',
#  'whatever good one abraham lincoln quote yall hoe',
#  'rt nigga catching attitude expect bitch beg plenty sorrys figure whats problem',
#  'phil kessel name sourced violate blp idiot',
#  'family countless friend must bury face',
#  'rt homeowner shoot armed suspect attacked pistol whipped httptcovluewugclg',
#  'ho bitch delete shit',
#  'put best face forward',
#  'related group info removed infobox dedicated editor page related group info removed infoboxes comment may left ethnic group talk page',
#  'tko idiot idea swinging neckbreaker unsmart unclever faggot got dark hooded smoker',
#  'welcome touch new height',
#  'flag day chinese flag full deeper meaning red background represents communist',
#  'boat',
#  'ty much lovely rose',
#  'wanna taken serious sign cm punk bigger contract veteran',
#  'rt muslim group slaughter child nigerian school child burned alive shot amp slit throat tried escape\n http',
#  'today parent celebrate year marriage love dedication share amazing anniversary mom dad',
#  'interesting take tragedy use soapbox preach jesus condemned religious aka',
#  'say big brother',
#  'rt old hoe madddd slayed attire',
#  'throw flag bitch aint real bush',
# ...
#  'take non footnoted bull shit entry serious either longer take world wiki b seriously either run bunch year old kid authority issue fuck',
#  'fuck ing ugly walter bitch another fat ugly loser prick site believe retard ed look faggot guess found live go ahead block ip anymore anyone future us wrong handle truth go around undoing good work never contributing good work bad reverts edits followed lot edits error see inconsistent incorrect one call cu dick suck as licker think dirt compensate bully consistent logical found dozen article listing people show parade activity event considered significant go around following article editor contribute put notice top remove work even year cu sore pussy loser dick suck men make feel better much loser think important going undoing work zillion ip admin could take site gonna wish never fuck ed crew meaningless worthless dick head piece shit fuck die read stupid notice reply fuck could care le location anymore matter fact location show ip search bounce location throw people like even city state registered haha joke hong kong ding dong already using ip edit article watch track dip shit good luck could care le article worked undid cu life p best wikipedia like claim get jealous mad effort get revenge go undo work spite shit already confirmed either work stop undoing edits acting like know as hole unproductive annoying psycho serious mental issue need put away like content give right undo cu cu prick delete ist ever heard talk page dispute resolution consensus think rule apply kiss as want end wanna career go away stop bull shit else yeah threat block ip awhile affect one bit white trash weird al looking nigger care someone fan people edit article fan expert topic grow go jerk rub cum long curly gross greasy looking hair call life gun use face lmfao',
#  'rt dont wanna hear sgt name come outta preezys mouth couldnt bothered keep pie ho',
#  'niell',
#  'premium staer kit today happy oiler handbook w purchase',
#  'dude beef spellcast dark magick tryed curse beef beef shall grow old moldy flame war ended st god men proven one bad film beefcake beefcake',
#  'rooster simulation want climb vast expanse mountain reached leakage cock want',
#  'ever hu bad emotionally hu physically',
#  'name upcoming new track',
#  'father day please gift hospital',
#  'safe way heal',
#  'rt dont want good girl hoe choice',
#  'fuck as hole fuck ing bastard son bitch as hole mother fuck er go fuck ur mother cunt trade ur wife sister',
#  'swap meet bound',
#  'moving back vancouver island month half excited',
#  'game winning hit thursday capped great career guy st ballot hof else',
#  'seeing yearold utilize vivid imagination create battle sequence transformer kirby',
#  'sun shining ready night hour',
#  'redirect talk carlos johnson musician',
#  'isi jihadis australia shoot man face chanting isi stay httptcoxyzxvlzs',
#  'got canadian work visa approved finally',
#  'rt iont like yall always talking even tryna funny thou rn bitch',
#  'fuck cunt block go head cunt licker',
#  'father day ur presence count ur present priest amp prophet home hero amp loverfather',
#  'hope dis aint cause colored cause know actin nigga like',
#  'hardly ever sober bitch party till',
#  'wtf fuck think vandalized nigger oklahoma city bombing prohibition page even page thank douschebag getting editing privilages revoked prick',
#  'rt video talking trash facing today scrimmage httptconjzfytcr httpt',
#  'hacker hacker correct term called cracker',
#  'dieting week staed stone stone',
#  'go stick icepick sku everyone favour',
#  'finally found way delete old tweet might find useful well',
#  'check saw day father day',
#  'hillary bigger lead poll obama point basis',
#  'wish since twitter cant remind follower today',
#  'ive met private idaho monday tkkim_a',
#  'rt salute derek jetter best yankee ever',
#  'become detective figuring oh yeah suck cock became wikipiedia admin lot time hand often feel good knowing ban people internet',
#  'staing withdrawal already fan',
#  'mood excited finale coming',
#  'true topic insist logic protestors perceive china dictatorship equlivalent represent anti dictatorial protestors never even heard thing sound like political framing would protest perceived dictatorship saudi arabia go protest china rarely anti dictatorial single classification even classification opinion would suggest lengthy wording e g supporter call individual freedom china',
#  'yall dont want nigga unless bitch want \n\nbut get get mad cuz bitch still want',
#  'cold war fought oil',
#  'rt hit pussy httptcotzdyatfu',
#  'join melania way',
#  'allinclusive holiday fab weve lovely time cant wait decent wine telly im pathetic homebody',
#  'belief openness close page bull shit see thru u jimbo wikipedia founder hit relationship trouble allegation excessive spending megan mccarthy march pmcategories people wikipedia founder jimmy wale good weekend first blogosphere wikipedia lit news messy breakup controversial canadian tv pundit rachel marsden accusation flying wale living high life expense account nonprofit foundation created friday report surfaced married divorcing internet icon carried clandestine affair marsden evidence affair included lurid im trans cripts appeared silicon valley gossip blog valleywag saturday wale posted statement wikipedia foundation website later moved personal site denying action went wikimedia foundation policy stating affair ended marsden responded listing clothes left house auction ebay big deal relationship go sour well two met marsden contacted wale help clean perceived error personal wikipedia page allegation wale used influence improperly make change former associate wale using scandal bring worry organization foundation former wikimedia exec danny wool left foundation last year wrote blog post insinuating wale used non profit foundation personal piggy bank expense wale tried apply foundation included bottle wine visit moscow massage parlor wool alleges according wool expense got hand wikimedia foundation took away wale corporate credit card occasion used wikimedia foundation personal advancement guide mission someone mission part found rather distressful wool told epicenter wale immediately respond request comment',
#  'isnt sad keep thinking youll change mind love back',
#  'yep source confirmed iggy concert last night trash',
#  'weeeellll know dont like travelso seen youre closemaybe twice xx',
#  'rt killer line josh smith dropped killer trash talk line kenneth httptcocdsjoupj',
#  'rt bitch swearing pussy soooo good nonsense',
#  'rt egg avi mention follower pussy bo dont want war',
#  'inchlatcock giving receiving oral sex im driving th',
#  'youth gt',
#  'pussymoneyweed nigga need',
#  'robin life',
#  'texting bitch like main material fuck shit finna get youza hoe text',
#  'yes favorite rt please tell didnt buy trash',
#  'cant sit still work',
#  'good morning lovely friend sunday cheerful day',
#  'checking everything ny bucket list im limiting posting pic day insta',
#  'rt surprising big pussy hulk',
#  'agree could also rewritten say law passed state followed w hate ver specifically law state',
#  'yes care prejudice',
#  'rt hoe aint loyal woman generation cannot trusted',
#  'even look edit reverting change wanted say rex think doesnt work said hit many thing also said elsewhere article making perfect lead stated elsewhere article source mean also use source source better would suggest stop touching article come clear reason added know well work one touch order finish dispute person want information article stop discussing think revert whenever page get changed',
#  'nok stronger test peak near',
#  'well thank also visit see',
#  'preceding unsigned comment added talk contribs hi danger breaking wp rr consecutive edits count one revert feel free undo last undo talk',
#  'gorilla simulator need adapt environment need tear city',
#  'find page number couple source removed time sure sub rosa source still appropriate able get library weekend remove source associated information pending confirmation page number',
#  'outdrawn outgunned fuckin weak dude',
#  'domino moonlit lake velvet underground honey whiskey white trash heaven accept ridiculebut tonight',
#  'andrew rolling grave breitba hijacked',
#  'much look forward summer bestie holiday mum',
#  'hoe shit',
#  'living life dream',
#  'rt quotable rt man aint appreciating pussy definitely gonna end another nigga mouth',
#  'look stunning n yet speaks',
#  'got pussy bllod',
#  'rt yankee p michael pineda ejected game substance found neck httptcocekgdovb http',
#  'siri reveals apple announce wwdc way cnet',
#  'give u w people moving give u stick fun',
#  'hitler called',
#  'slutty as dyke',
#  'mom act like bitch doe like ok ur losing ur memory dont cunt ur daughter',
#  'bcaas shipping today friday',
#  'fuck care',
#  'next update would amazin two celebration added shirt well take yellow rko',
#  'answer relates studying group dont think ur struggle relevant',
#  'thats kevin hoe',
#  'rt hoe fake like really fck hating lowkey',
#  'need day today',
#  'bastard hope dog dy',
#  'bull dominate bull direct whatever want',
#  'effin peice sheet suuck',
#  'trust noneeee bitch dont',
#  'rt bitch came yeah threw party httptcotwnbyvlrz',
#  'rt paid k mile bitch always money httptcopqsazlt',
#  'one good back year precise',
#  'intention stop dick use template image workshop page second worth contemplation part would show method stupid particular page method stupid would good idea use method stupid work done long time',
#  'well since non specialized literature british english surprised using anglo britton specific expletive',
#  'stop changon fuck en moron runnen stop workon fuck jeorge bush stop changon page stop beon mene name jassel mubedian war iraq stop changon cunt rey page stop also',
#  'little disappointed lol fb access vpns',
#  'rt bacon bitch',
#  'wile e coyote e beep beep',
#  'everything except trust hoe',
#  'watched original amp made happy ill watch prepare new',
#  'egypt r muzzie bros still running thing tad better certainly respectors dem though',
#  'salute hoe kno place bitch miss',
#  'brunch',
#  'almost time travel',
#  'try official website shit head',
#  'go fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourselfgo fuck yourse ...
#  'stone rose day',
#  'dont say shit like lil nig ill give stamp',
#  'amazing',
#  'always',
#  'optimistic',
#  'well im sure im fully retarded',
#  'fuck fuck fuck',
#  'like dat name dem sand nigger need know dare place da pecker order',
#  'would like wish day',
#  'yesterday ozen',
#  'going hear garbage childesh clown another month',
#  'saturday',
#  'common way people give power thinking dont alice walker',
#  'please refrain adding nonsense wikipedia bit plane considered vandalism would like experiment use sandbox link edit reverted found link believe edit reverted please contact',
#  'nigga aint shit hoe trick',
#  'flipping back forth playoff baseball trainwreck formerly known new york jet',
#  'rt getting painful experience like crossing monkey bar let go point order move forward',
#  'great dumb crybaby pussy',
#  'see already know faggot lmao',
#  'true',
#  'work',
#  'dont follow unfollow retarded',
#  'yes biggest thing youve got week picking dole money',
#  'rt always bitch opposite sex equally scandalous large sum hypocrisy',
#  'cant talk anyone go answer littlephone call little bitch low bathroom foh',
#  'crazy much ive changed last june month june happy year anniversary new self',
#  'gtgt',
#  'proof every monday morning suck',
#  'fuck right pussy',
#  'info typespos poetry news chk kro agr maza na aya stop follow',
#  'sure',
#  'read make',
#  'another innocent soul born corrupt family',
#  'getting goody bag ready tomorrow night',
#  'hope guy fantastic summer get fun',
#  'he worse president history country yet american approve',
#  'mrrat phantomaviation cptplanespotter blackmaverick wbruchal ufeellucky spad',
#  'happy hour amp sing k ing colleague hour',
#  'close',
#  'unblock unblock restriction editing jackass trying edit like everyone else first post serious constructive douche bag deleted immediately warned shit everyone anything site bull shit cause create account mean stuff edit legit piss',
#  'love toy swap',
#  ...]

# %%
# Create the Sent2Vec Vectorizer and embed the sentences
vectorizer = Vectorizer()
vectorizer.run(sentences)
vectors = vectorizer.vectors
vectors
# Out:
# Initializing Bert distilbert-base-uncased
# Vectorization done on cpu
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertModel: ['vocab_projector.bias', 'vocab_transform.bias', 'vocab_transform.weight', 'vocab_projector.weight', 'vocab_layer_norm.bias', 'vocab_layer_norm.weight']
# - This IS expected if you are initializing DistilBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Token indices sequence length is longer than the specified maximum sequence length for this model (945 > 512). Running this sequence through the model will result in indexing errors
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-eb65f9a45282> in <module>
#       1 vectorizer = Vectorizer()
# ----> 2 vectorizer.run(sentences)
#       3 vectors = vectorizer.vectors
#       4 vectors
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sent2vec/vectorizer.py in run(self, sentences, remove_stop_words, add_stop_words)
#      41                 raise TypeError(f'All items must be string type but {sentence} is type {type(sentence)}.')
#      42         # RUN
# ---> 43         self.vectorizer._execute(sentences, remove_stop_words=remove_stop_words, add_stop_words=add_stop_words)
#      44         vectors = self.vectorizer.vectors
#      45         for idx in range(vectors.shape[0]):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sent2vec/vectorizer.py in _execute(self, sentences, **kwargs)
#      77         model = self.model.to(self.device)
#      78         model.eval()
# ---> 79         tokenized = list(map(lambda x: self.tokenizer.encode(x, add_special_tokens=True), sentences))
#      80         max_len = 0
#      81         for i in tokenized:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sent2vec/vectorizer.py in <lambda>(x)
#      77         model = self.model.to(self.device)
#      78         model.eval()
# ---> 79         tokenized = list(map(lambda x: self.tokenizer.encode(x, add_special_tokens=True), sentences))
#      80         max_len = 0
#      81         for i in tokenized:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/transformers/tokenization_utils_base.py in encode(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, return_tensors, **kwargs)
#    2285             stride=stride,
#    2286             return_tensors=return_tensors,
# -> 2287             **kwargs,
#    2288         )
#    2289
#
# ~/opt/anaconda3/lib/python3.7/site-packages/transformers/tokenization_utils_base.py in encode_plus(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2626             return_length=return_length,
#    2627             verbose=verbose,
# -> 2628             **kwargs,
#    2629         )
#    2630
#
# ~/opt/anaconda3/lib/python3.7/site-packages/transformers/tokenization_utils.py in _encode_plus(self, text, text_pair, add_special_tokens, padding_strategy, truncation_strategy, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#     647             )
#     648
# --> 649         first_ids = get_input_ids(text)
#     650         second_ids = get_input_ids(text_pair) if text_pair is not None else None
#     651
#
# ~/opt/anaconda3/lib/python3.7/site-packages/transformers/tokenization_utils.py in get_input_ids(text)
#     614         def get_input_ids(text):
#     615             if isinstance(text, str):
# --> 616                 tokens = self.tokenize(text, **kwargs)
#     617                 return self.convert_tokens_to_ids(tokens)
#     618             elif isinstance(text, (list, tuple)) and len(text) > 0 and isinstance(text[0], str):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/transformers/tokenization_utils.py in tokenize(self, text, **kwargs)
#     545                 tokenized_text.append(token)
#     546             else:
# --> 547                 tokenized_text.extend(self._tokenize(token))
#     548         # ["This", " is", " something", "<special_token_1>", "else"]
#     549         return tokenized_text
#
# ~/opt/anaconda3/lib/python3.7/site-packages/transformers/models/bert/tokenization_bert.py in _tokenize(self, text)
#     242         split_tokens = []
#     243         if self.do_basic_tokenize:
# --> 244             for token in self.basic_tokenizer.tokenize(text, never_split=self.all_special_tokens):
#     245
#     246                 # If the token is part of the never_split set
#
# ~/opt/anaconda3/lib/python3.7/site-packages/transformers/models/bert/tokenization_bert.py in tokenize(self, text, never_split)
#     429                 elif self.strip_accents:
#     430                     token = self._run_strip_accents(token)
# --> 431             split_tokens.extend(self._run_split_on_punc(token, never_split))
#     432
#     433         output_tokens = whitespace_tokenize(" ".join(split_tokens))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/transformers/models/bert/tokenization_bert.py in _run_split_on_punc(self, text, never_split)
#     455         while i < len(chars):
#     456             char = chars[i]
# --> 457             if _is_punctuation(char):
#     458                 output.append([char])
#     459                 start_new_word = True
#
# ~/opt/anaconda3/lib/python3.7/site-packages/transformers/tokenization_utils.py in _is_punctuation(char)
#     292 def _is_punctuation(char):
#     293     """Checks whether `char` is a punctuation character."""
# --> 294     cp = ord(char)
#     295     # We treat all non-letter/number ASCII as punctuation.
#     296     # Characters such as "^", "$", and "`" are not in the Unicode
#
# KeyboardInterrupt:
